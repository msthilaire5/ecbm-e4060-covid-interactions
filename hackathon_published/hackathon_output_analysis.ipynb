# %% [markdown]
# # Mount GDrive & Set Up Paths

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

DATA = Path("/content/drive/MyDrive/ecbm-e4060-covid-interactions/DATA/Hackathon/output/ecbm-project-unzipped")

# %% [markdown]
# # Analyzing Genome Hits TSVs

# %% [markdown]
# ## From Megan's Output

# %%
genome_hits_file = "genome_hits.tsv"
f_utr_hits_file = "f_utr_hits.tsv"
t_utr_hits_file = "t_utr_hits.tsv"
genome_neg_hits_file = "genome_neg_hits.tsv"

# %%
import pandas as pd

genome_hits = pd.read_csv(DATA / genome_hits_file, sep="\t")

# %%
genome_hits
# Out:
#    Gene_name strand     N  ...          z          pval          qval
# 1     HNRNPL      +   632  ...  12.136256  3.393040e-34  3.359110e-32
# 2        FUS      +   140  ...  10.033817  5.412465e-24  2.679170e-22
# 3      MBNL1      +   682  ...   9.270263  9.284393e-21  3.063850e-19
# 4      SRSF1      +   335  ...   7.599590  1.485356e-14  3.676257e-13
# 5    RBMY1A1      +   107  ...   6.873108  3.140901e-12  6.218984e-11
# 6      ZFP36      +   609  ...   6.782333  5.912525e-12  9.755666e-11
# 7     SRSF10      +    88  ...   6.430755  6.348569e-11  8.978690e-10
# 8      PTBP1      +  3151  ...   6.017577  8.852336e-10  1.095477e-08
# 9      SRSF3      +    74  ...   5.469503  2.256495e-08  2.482145e-07
# 10      YBX2      +    51  ...   5.447163  2.558971e-08  2.533382e-07
# 11    PABPC1      +   118  ...   4.916742  4.399830e-07  3.959847e-06
# 12    PABPN1      +    50  ...   4.703132  1.281001e-06  1.056826e-05
# ...

# %%
f_utr_hits = pd.read_csv(DATA / f_utr_hits_file, sep="\t")
t_utr_hits = pd.read_csv(DATA / t_utr_hits_file, sep="\t")
genome_neg_hits = pd.read_csv(DATA / genome_neg_hits_file, sep="\t")

# %%
f_utr_hits
# Out:
#   Gene_name strand  N  mean_count  sd_count         z      pval      qval
# 1    ZRANB2      +  4      0.9124  0.923307  3.344065  0.000413  0.003922

# %%
t_utr_hits
# Out:
#   Gene_name strand   N  ...          z           pval           qval
# 1    PABPC4      +  27  ...  24.977498  5.368412e-138  1.986313e-136
# 2     SART3      +  28  ...  22.758430  5.920507e-115  1.095294e-113
# 3    SRSF10      +  27  ...  18.861758   1.176334e-79   1.450812e-78
# 4    PABPC1      +  28  ...  18.781304   5.370450e-79   4.967666e-78
# 5   KHDRBS3      +  28  ...  14.831251   4.600143e-50   3.404106e-49
# 6    LIN28A      +   3  ...   6.013317   9.088256e-10   5.604424e-09
# 7      PPIE      +  42  ...   5.019315   2.592798e-07   1.065928e-06
# 8   HNRNPA1      +   4  ...   3.751682   8.782617e-05   3.249568e-04
#
# [8 rows x 8 columns]

# %%
genome_neg_hits
# Out:
#    Gene_name strand    N  ...          z          pval          qval
# 1      NOVA2      -   95  ...  12.258053  7.605528e-35  7.301307e-33
# 2       YBX1      -  361  ...  11.350795  3.674557e-30  1.763787e-28
# 3     HNRNPL      -  769  ...  11.092410  6.827913e-29  2.184932e-27
# 4      NOVA1      -  918  ...  11.006947  1.768949e-28  4.245479e-27
# 5       YBX2      -   92  ...  10.017848  6.362155e-24  1.221534e-22
# 6      CELF2      -  619  ...   7.151721  4.284833e-13  6.855734e-12
# 7      SRSF3      -   88  ...   6.260941  1.913302e-10  2.623957e-09
# 8      CELF6      -   30  ...   5.081369  1.873625e-07  2.248351e-06
# 9     ELAVL1      -  104  ...   4.158536  1.601472e-05  1.708237e-04
# 10      TIA1      -  998  ...   4.089808  2.158654e-05  2.072308e-04
# 11     CELF4      -   20  ...   3.813215  6.858536e-05  5.486828e-04
# 12       FUS      -   72  ...   3.813621  6.847281e-05  5.486828e-04
# 13     ZFP36      -  505  ...   3.211836  6.594477e-04  4.869767e-03
# ...

# %% [markdown]
# ## From Karina's Output

# %%
KI_DATA = Path("/content/drive/MyDrive/ecbm-e4060-covid-interactions/DATA/Hackathon/output/ki-results")

# %%
ki_genome_hits = pd.read_csv(KI_DATA / genome_hits_file, sep="\t")
ki_f_utr_hits = pd.read_csv(KI_DATA / f_utr_hits_file, sep="\t")
ki_t_utr_hits = pd.read_csv(KI_DATA / t_utr_hits_file, sep="\t")
ki_genome_neg_hits = pd.read_csv(KI_DATA / genome_neg_hits_file, sep="\t")

# %%
ki_genome_hits
# Out:
#    Gene_name strand     N  ...          z          pval          qval
# 1     HNRNPL      +   632  ...  12.075008  7.157531e-34  7.085956e-32
# 2        FUS      +   140  ...  10.552335  2.477497e-26  1.226361e-24
# 3      MBNL1      +   682  ...   9.353181  4.252541e-21  1.403339e-19
# 4      SRSF1      +   335  ...   7.488976  3.470646e-14  8.589849e-13
# 5    RBMY1A1      +   107  ...   6.987404  1.400092e-12  2.772182e-11
# 6      ZFP36      +   609  ...   6.782399  5.909821e-12  9.751205e-11
# 7     SRSF10      +    88  ...   6.422941  6.683299e-11  9.452095e-10
# 8      PTBP1      +  3151  ...   5.920488  1.604938e-09  1.986111e-08
# 9       YBX2      +    51  ...   5.453245  2.472947e-08  2.720242e-07
# 10     SRSF3      +    74  ...   5.425103  2.896061e-08  2.867100e-07
# 11    PABPC1      +   118  ...   4.929721  4.117351e-07  3.705616e-06
# 12    PABPN1      +    50  ...   4.818234  7.241708e-07  5.974409e-06
# ...

# %%
ki_f_utr_hits
# Out:
#   Gene_name strand  N  mean_count  sd_count         z      pval      qval
# 1    ZRANB2      +  4      0.9132    0.9236  3.342141  0.000416  0.003949

# %%
ki_t_utr_hits
# Out:
#   Gene_name strand   N  ...          z           pval           qval
# 1    PABPC4      +  27  ...  25.108129  2.026962e-139  7.499760e-138
# 2     SART3      +  28  ...  22.594349  2.462593e-113  4.555796e-112
# 3    PABPC1      +  28  ...  18.911272   4.605438e-80   5.680040e-79
# 4    SRSF10      +  27  ...  18.695139   2.711437e-78   2.508079e-77
# 5   KHDRBS3      +  28  ...  14.517585   4.687752e-48   3.468937e-47
# 6    LIN28A      +   3  ...   6.043128   7.557728e-10   4.660599e-09
# 7      PPIE      +  42  ...   5.088977   1.800000e-07   7.399998e-07
# 8   HNRNPA1      +   4  ...   3.740120   9.196624e-05   3.402751e-04
#
# [8 rows x 8 columns]

# %%
ki_genome_neg_hits
# Out:
#    Gene_name strand    N  ...          z          pval          qval
# 1      NOVA2      -   95  ...  12.370490  1.887545e-35  1.812043e-33
# 2       YBX1      -  361  ...  11.486870  7.678840e-31  3.685843e-29
# 3      NOVA1      -  918  ...  11.228229  1.481794e-29  4.741741e-28
# 4     HNRNPL      -  769  ...  11.058703  9.947639e-29  2.387433e-27
# 5       YBX2      -   92  ...   9.917461  1.747669e-23  3.355524e-22
# 6      CELF2      -  619  ...   6.988200  1.392173e-12  2.227477e-11
# 7      SRSF3      -   88  ...   6.241641  2.165026e-10  2.969178e-09
# 8      CELF6      -   30  ...   5.069709  1.992126e-07  2.390551e-06
# 9     ELAVL1      -  104  ...   4.157687  1.607432e-05  1.714594e-04
# 10      TIA1      -  998  ...   4.110909  1.970524e-05  1.891703e-04
# 11     CELF4      -   20  ...   3.776978  7.937142e-05  6.719824e-04
# 12       FUS      -   72  ...   3.762839  8.399780e-05  6.719824e-04
# 13     ZFP36      -  505  ...   3.226549  6.264636e-04  4.626193e-03
# ...

# %% [markdown]
# ## Quick comparison without doing set difference

# %%
genome_hits[genome_hits.Gene_name.isin(ki_genome_hits.Gene_name)]
# Out:
#    Gene_name strand     N  ...          z          pval          qval
# 1     HNRNPL      +   632  ...  12.136256  3.393040e-34  3.359110e-32
# 2        FUS      +   140  ...  10.033817  5.412465e-24  2.679170e-22
# 3      MBNL1      +   682  ...   9.270263  9.284393e-21  3.063850e-19
# 4      SRSF1      +   335  ...   7.599590  1.485356e-14  3.676257e-13
# 5    RBMY1A1      +   107  ...   6.873108  3.140901e-12  6.218984e-11
# 6      ZFP36      +   609  ...   6.782333  5.912525e-12  9.755666e-11
# 7     SRSF10      +    88  ...   6.430755  6.348569e-11  8.978690e-10
# 8      PTBP1      +  3151  ...   6.017577  8.852336e-10  1.095477e-08
# 9      SRSF3      +    74  ...   5.469503  2.256495e-08  2.482145e-07
# 10      YBX2      +    51  ...   5.447163  2.558971e-08  2.533382e-07
# 11    PABPC1      +   118  ...   4.916742  4.399830e-07  3.959847e-06
# 12    PABPN1      +    50  ...   4.703132  1.281001e-06  1.056826e-05
# ...

# %%
t_utr_hits[t_utr_hits.Gene_name.isin(ki_t_utr_hits.Gene_name)]
# Out:
#   Gene_name strand   N  ...          z           pval           qval
# 1    PABPC4      +  27  ...  24.977498  5.368412e-138  1.986313e-136
# 2     SART3      +  28  ...  22.758430  5.920507e-115  1.095294e-113
# 3    SRSF10      +  27  ...  18.861758   1.176334e-79   1.450812e-78
# 4    PABPC1      +  28  ...  18.781304   5.370450e-79   4.967666e-78
# 5   KHDRBS3      +  28  ...  14.831251   4.600143e-50   3.404106e-49
# 6    LIN28A      +   3  ...   6.013317   9.088256e-10   5.604424e-09
# 7      PPIE      +  42  ...   5.019315   2.592798e-07   1.065928e-06
# 8   HNRNPA1      +   4  ...   3.751682   8.782617e-05   3.249568e-04
#
# [8 rows x 8 columns]

# %%
genome_neg_hits[genome_neg_hits.Gene_name.isin(ki_genome_neg_hits.Gene_name)]
# Out:
#    Gene_name strand    N  ...          z          pval          qval
# 1      NOVA2      -   95  ...  12.258053  7.605528e-35  7.301307e-33
# 2       YBX1      -  361  ...  11.350795  3.674557e-30  1.763787e-28
# 3     HNRNPL      -  769  ...  11.092410  6.827913e-29  2.184932e-27
# 4      NOVA1      -  918  ...  11.006947  1.768949e-28  4.245479e-27
# 5       YBX2      -   92  ...  10.017848  6.362155e-24  1.221534e-22
# 6      CELF2      -  619  ...   7.151721  4.284833e-13  6.855734e-12
# 7      SRSF3      -   88  ...   6.260941  1.913302e-10  2.623957e-09
# 8      CELF6      -   30  ...   5.081369  1.873625e-07  2.248351e-06
# 9     ELAVL1      -  104  ...   4.158536  1.601472e-05  1.708237e-04
# 10      TIA1      -  998  ...   4.089808  2.158654e-05  2.072308e-04
# 11     CELF4      -   20  ...   3.813215  6.858536e-05  5.486828e-04
# 12       FUS      -   72  ...   3.813621  6.847281e-05  5.486828e-04
# 13     ZFP36      -  505  ...   3.211836  6.594477e-04  4.869767e-03
# ...
